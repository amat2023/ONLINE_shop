# %%
import pandas as pd

Online_Shop =pd.read_csv("/Users/amatnasr/Downloads/Online Shop Customer Sales Data.csv")

# %%
Online_Shop
# Out:
#        Customer_id  Age  Gender  Revenue_Total  N_Purchases Purchase_DATE  \
# 0           504308   53       0           45.3            2      22.06.21
# 1           504309   18       1           36.2            3      10.12.21
# 2           504310   52       1           10.6            1      14.03.21
# 3           504311   29       0           54.1            5      25.10.21
# 4           504312   21       1           56.9            1      14.09.21
# ...            ...  ...     ...            ...          ...           ...
# 65791       570099   30       1           10.9            4      15.02.21
# 65792       570100   33       0           29.3            1      05.02.21
# 65793       570101   50       0           25.4            5      29.10.21
# 65794       570102   56       0           29.2            1      09.12.21
# 65795       570103   25       0            5.3            2      23.10.21
#
#        Purchase_VALUE  Pay_Method  Time_Spent  Browser  Newsletter  Voucher
# ...

# %%
Online_Shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65796 entries, 0 to 65795
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer_id     65796 non-null  int64
#  1   Age             65796 non-null  int64
#  2   Gender          65796 non-null  int64
#  3   Revenue_Total   65796 non-null  float64
#  4   N_Purchases     65796 non-null  int64
#  5   Purchase_DATE   65796 non-null  object
#  6   Purchase_VALUE  65796 non-null  float64
#  7   Pay_Method      65796 non-null  int64
#  8   Time_Spent      65796 non-null  int64
#  9   Browser         65796 non-null  int64
#  10  Newsletter      65796 non-null  int64
#  11  Voucher         65796 non-null  int64
# dtypes: float64(2), int64(9), object(1)
# memory usage: 6.0+ MB

# %%
Online_Shop.describe().T
# Out:
#                   count           mean           std         min  \
# Customer_id     65796.0  537205.500000  18993.813493  504308.000
# Age             65796.0      39.592696     13.825466      16.000
# Gender          65796.0       0.671348      0.469727       0.000
# Revenue_Total   65796.0      27.732935     14.941878       0.500
# N_Purchases     65796.0       3.992477      2.004370       1.000
# Purchase_VALUE  65796.0      15.968699     13.229295       0.005
# Pay_Method      65796.0       1.308651      1.081959       0.000
# Time_Spent      65796.0     598.925603    277.833635     120.000
# Browser         65796.0       0.630935      0.996407       0.000
# Newsletter      65796.0       0.151027      0.358078       0.000
# Voucher         65796.0       0.250258      0.433165       0.000
#
#                          25%        50%         75%       max
# Customer_id     520756.75000  537205.50  553654.250  570103.0
# ...

# %%
Online_Shop.head(10)
# Out:
#    Customer_id  Age  Gender  Revenue_Total  N_Purchases Purchase_DATE  \
# 0       504308   53       0           45.3            2      22.06.21
# 1       504309   18       1           36.2            3      10.12.21
# 2       504310   52       1           10.6            1      14.03.21
# 3       504311   29       0           54.1            5      25.10.21
# 4       504312   21       1           56.9            1      14.09.21
# 5       504313   55       0           13.7            6      14.05.21
# 6       504314   17       1           30.7            6      09.01.21
# 7       504315   30       1            8.1            7      28.03.21
# 8       504316   51       0           18.0            4      04.08.21
# 9       504317   63       1           19.2            4      06.10.21
#
#    Purchase_VALUE  Pay_Method  Time_Spent  Browser  Newsletter  Voucher
# 0          24.915           1         885        0           0        0
# ...

# %%
Online_Shop.loc[Online_Shop.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Customer_id, Age, Gender, Revenue_Total, N_Purchases, Purchase_DATE, Purchase_VALUE, Pay_Method, Time_Spent, Browser, Newsletter, Voucher]
# Index: []

# %%
#Change the Gender to Str :

# %%
Online_Shop['Gender_String'] = Online_Shop['Gender'].replace({0: 'Male', 1: 'Female'})
Online_Shop['Gender_String']
# Out:
# 0          Male
# 1        Female
# 2        Female
# 3          Male
# 4        Female
#           ...
# 65791    Female
# 65792      Male
# 65793      Male
# 65794      Male
# 65795      Male
# Name: Gender_String, Length: 65796, dtype: object

# %%
#Change Time to minutes :

# %%
Online_Shop['Time_Spent_minutes'] = (Online_Shop['Time_Spent'] / 60).round(2)
print('--------------------------------------------------------------------------------')
# Out:
# --------------------------------------------------------------------------------

# %%
#Average time by gender:

# %%
Average_time_by_gender = Online_Shop.groupby('Gender_String')['Time_Spent_minutes'].mean()  	
Average_time_by_gender
# Out:
# Gender_String
# Female    9.98725
# Male      9.97155
# Name: Time_Spent_minutes, dtype: float64

# %%
import matplotlib.pyplot as plt

Average_time_by_gender = Online_Shop.groupby('Gender_String')['Time_Spent_minutes'].mean()  	

Average_time_by_gender.plot(kind='bar', color=['r', 'green'])
plt.title('Average time in minutes by gender')
plt.xlabel('gender')
plt.ylabel('Average time in minutes')
plt.show()

# %%
#Average Revenue by gender:

# %%
import matplotlib.pyplot as plt

Average_Revenue_by_gender = Online_Shop.groupby('Gender_String')['Revenue_Total'].mean()  	

Average_Revenue_by_gender.plot(kind='bar', color=['r', 'green'])
plt.title('Average Revenue by gender')
plt.xlabel('gender')
plt.ylabel('Average Revenue')
plt.show()
print('--------------------------------------------------------------------------------')
# Out:
# --------------------------------------------------------------------------------

# %%
#Most Common Payment Method :

# %%
Online_Shop['Pay_Method'] = Online_Shop['Pay_Method'].replace({0: 'Digitale Geldbörsen', 1: 'Karte' , 2: 'PayPal' , 3: 'Andere'})
Online_Shop['Pay_Method']
# Out:
# 0                      Karte
# 1                     PayPal
# 2        Digitale Geldbörsen
# 3                      Karte
# 4                      Karte
#                 ...
# 65791                  Karte
# 65792    Digitale Geldbörsen
# 65793                 Andere
# 65794                 Andere
# 65795    Digitale Geldbörsen
# Name: Pay_Method, Length: 65796, dtype: object

# %%
most_payment_method = Online_Shop['Pay_Method'].value_counts()
most_payment_method
# Out:
# Pay_Method
# Karte                  19754
# Digitale Geldbörsen    19075
# PayPal                 14551
# Andere                 12416
# Name: count, dtype: int64

# %%
# Distribution of Payment Methods:

# %%
import matplotlib.pyplot as plt

most_payment_method = Online_Shop['Pay_Method'].value_counts()

# Create a bar chart
plt.bar(most_payment_method.index, most_payment_method)

# Add labels and title
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.title('Distribution of Payment Methods')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

most_payment_method = Online_Shop['Pay_Method'].value_counts()

plt.pie(most_payment_method, labels=most_payment_method.index, autopct='%1.1f%%', startangle=60)
plt.title('Distribution of Payment Methods')
plt.show()
print('--------------------------------------------------------------------------------')
# Out:
# --------------------------------------------------------------------------------

# %%
# Distribution of Purchases :

# %%
Online_Shop[Online_Shop['N_Purchases'] == 1]['N_Purchases'].count()
# Out:
# 9519

# %%
Online_Shop[Online_Shop['N_Purchases'] == 4]['N_Purchases'].count()
# Out:
# 9258

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
sns.countplot(x='N_Purchases', data=Online_Shop, color='skyblue', order=Online_Shop['N_Purchases'].value_counts().index)
plt.title('Distribution of Purchases')
plt.xlabel('Number of Purchases')
plt.ylabel('Count')
plt.show()

# %%
# Distribution of Purchase Values :

# %%
Online_Shop['Purchase_VALUE']
# Out:
# 0        24.915
# 1         2.896
# 2        10.600
# 3        43.280
# 4        56.900
#           ...
# 65791     6.213
# 65792    29.300
# 65793    23.114
# 65794    29.200
# 65795     2.968
# Name: Purchase_VALUE, Length: 65796, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(Online_Shop['Purchase_VALUE'], bins=10, color='skyblue', edgecolor='black')

plt.title('Distribution of Purchase Values')
plt.xlabel('Purchase Value')
plt.ylabel('Frequency')
plt.show()

# %%
#Change Purchase_DATE to datetime :

# %%
Online_Shop['Purchase_DATE'] = pd.to_datetime(Online_Shop['Purchase_DATE'])
Online_Shop['Purchase_DATE']
# Out:
# /var/folders/11/9c6m5th568j9r_zj5yr6slf00000gn/T/ipykernel_18121/429110058.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Online_Shop['Purchase_DATE'] = pd.to_datetime(Online_Shop['Purchase_DATE'])
# 0       2021-06-22
# 1       2021-10-12
# 2       2021-03-14
# 3       2021-10-25
# 4       2021-09-14
#            ...
# 65791   2021-02-15
# 65792   2021-05-02
# 65793   2021-10-29
# 65794   2021-09-12
# 65795   2021-10-23
# Name: Purchase_DATE, Length: 65796, dtype: datetime64[ns]

# %%
# Total Revenue :

# %%
Online_Shop['Revenue_Total']
# Out:
# 0        45.3
# 1        36.2
# 2        10.6
# 3        54.1
# 4        56.9
#          ...
# 65791    10.9
# 65792    29.3
# 65793    25.4
# 65794    29.2
# 65795     5.3
# Name: Revenue_Total, Length: 65796, dtype: float64

# %%
# Total Revenue Over Time:

# %%
total_revenue_over_time = Online_Shop.groupby('Purchase_DATE')['Revenue_Total'].sum()
total_revenue_over_time
# Out:
# Purchase_DATE
# 01.01.21    5334.4
# 01.01.22    4890.5
# 01.02.21    4287.8
# 01.03.21    4008.9
# 01.04.21    5386.8
#              ...
# 31.05.21    5265.3
# 31.07.21    4380.9
# 31.08.21    4748.5
# 31.10.21    4841.0
# 31.12.21    4970.0
# Name: Revenue_Total, Length: 366, dtype: float64

# %%
# Monthly Revenue:

# %%
monthly_revenue = Online_Shop.resample('M', on='Purchase_DATE')['Revenue_Total'].sum()

plt.figure(figsize=(12, 6))
monthly_revenue.plot(kind='bar', color='blue')
plt.title('Monthly Revenue Trends')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.grid(True)
plt.show()

# %%
# Monthly Purchase value :

# %%
monthly_Purchase_Value = Online_Shop.resample('M', on='Purchase_DATE')['Purchase_VALUE'].sum()

plt.figure(figsize=(12, 6))
monthly_Purchase_Value.plot(kind='bar', color='blue')
plt.title('Monthly Purchase value')
plt.xlabel('Month')
plt.ylabel('Total Purchase')
plt.grid(True)
plt.show()

# %%
# Distribution of the 'Browser', 'Newsletter', 'Voucher':

# %%
for column in ['Browser', 'Newsletter', 'Voucher']:		
    plt.figure(figsize=(8, 4))
    
    
    order = sorted(Online_Shop[column].unique())
    
    sns.countplot(x=column, data=Online_Shop, palette='Set1', order=order)
   
    plt.title(f'Verteilung von {column.capitalize()}')
 
    plt.show()
# Out:
# /var/folders/11/9c6m5th568j9r_zj5yr6slf00000gn/T/ipykernel_18121/112526191.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=Online_Shop, palette='Set1', order=order)
# /var/folders/11/9c6m5th568j9r_zj5yr6slf00000gn/T/ipykernel_18121/112526191.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=column, data=Online_Shop, palette='Set1', order=order)
# /var/folders/11/9c6m5th568j9r_zj5yr6slf00000gn/T/ipykernel_18121/112526191.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# Total Purchase by Age :

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=Online_Shop, x='Age', y='Purchase_VALUE', marker='o',ms = 5, mec = 'b', mfc = 'r')

plt.title('Purchase value by Age')
plt.xlabel('Age')
plt.ylabel('Purchase VALUE')

plt.show()

# %%
tuple_temp= []
def Age(Age):
    

    if Age < 18:
        return 'kids'
    elif 18 <= Age < 25:
        return 'Teeneger'
    elif 25 <= Age < 35:
        return 'young adult'
    elif 35 <= Age < 50:
        return 'adults'
    elif 50 <= Age < 65:
        return 'seniors'

# %%
Online_Shop ['Age'] = Online_Shop.apply (lambda x: Age (x['Age']), axis=1)
Online_Shop ["Age"]
# Out:
# 0            seniors
# 1           Teeneger
# 2            seniors
# 3        young adult
# 4           Teeneger
#             ...
# 65791    young adult
# 65792    young adult
# 65793        seniors
# 65794        seniors
# 65795    young adult
# Name: Age, Length: 65796, dtype: object

# %%
Online_Shop
# Out:
#        Customer_id          Age  Gender  Revenue_Total  N_Purchases  \
# 0           504308      seniors       0           45.3            2
# 1           504309     Teeneger       1           36.2            3
# 2           504310      seniors       1           10.6            1
# 3           504311  young adult       0           54.1            5
# 4           504312     Teeneger       1           56.9            1
# ...            ...          ...     ...            ...          ...
# 65791       570099  young adult       1           10.9            4
# 65792       570100  young adult       0           29.3            1
# 65793       570101      seniors       0           25.4            5
# 65794       570102      seniors       0           29.2            1
# 65795       570103  young adult       0            5.3            2
#
#       Purchase_DATE  Purchase_VALUE           Pay_Method  Time_Spent  Browser  \
# ...

# %%
total_purchase_by_age = Online_Shop.groupby('Age')['Purchase_VALUE'].count()
total_purchase_by_age
# Out:
# Age
# Teeneger        9420
# adults         20707
# kids            2697
# seniors        19268
# young adult    13704
# Name: Purchase_VALUE, dtype: int64

# %%
plt.figure(figsize=(10, 8))
total_purchase_by_age.sort_values().plot(kind='bar', color='blue')
plt.title('Total Purchase by Age')
plt.xlabel('Age Group')
plt.ylabel('Total Purchase')
plt.grid(True)
plt.show()

# %%
Pay_method_by_age = Online_Shop.groupby('Age')['Pay_Method'].value_counts()
total_purchase_by_age
# Out:
# Age
# Teeneger        9420
# adults         20707
# kids            2697
# seniors        19268
# young adult    13704
# Name: Purchase_VALUE, dtype: int64

# %%
plt.figure(figsize=(10, 8))
Pay_method_by_age.sort_values().plot(kind='bar')
plt.title('Pay Method by Age')
plt.xlabel('Age Group')
plt.ylabel('Pay Method')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=Online_Shop, x='Age', hue='Pay_Method', palette='muted')

plt.title('Pay Method Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Pay Method', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
